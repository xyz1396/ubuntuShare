# %%
# %matplotlib inline
import pandas as pd
import lxml
import dask.dataframe as dd
from pandas_plink import read_plink
import numpy as np

# %%
phenotypes=dd.read_csv("/work/biobank/ukb_data/ukbt_maindf.csv")

# %%
for i in phenotypes.columns.values:
    if ("Name" in i):
        print(i)

# %%
phenotypes.columns.values

# %%
pheno=pd.read_csv("/work/biobank/ukb_data/ukbt_maindf.csv", usecols=["eid","age_diabetes_diagnosed_f2976_0_0","age_diabetes_diagnosed_f2976_1_0","age_diabetes_diagnosed_f2976_2_0","age_diabetes_diagnosed_f2976_3_0"],low_memory=False)

# %%
a1=pheno[pheno["age_diabetes_diagnosed_f2976_0_0"].notna()][["eid"]]

# %%
a2=pheno[pheno["age_diabetes_diagnosed_f2976_1_0"].notna()][["eid"]]

# %%
a3=pheno[pheno["age_diabetes_diagnosed_f2976_2_0"].notna()][["eid"]]

# %%
a4=pheno[pheno["age_diabetes_diagnosed_f2976_3_0"].notna()][["eid"]]

# %%
a5=pheno[pheno["age_diabetes_diagnosed_f2976_3_0"].notna()][["eid"]]

# %%
a6=pheno[pheno["age_diabetes_diagnosed_f2976_3_0"].notna()][["eid"]]

# %%
a7=pheno[pheno["age_diabetes_diagnosed_f2976_3_0"].notna()][["eid"]]

# %%
a8=pheno[pheno["age_diabetes_diagnosed_f2976_3_0"].notna()][["eid"]]

# %%
eids=pd.concat([a1,a2,a3,a4],axis=0)#a5,a6,a7,a8],axis=0)

# %%
eids=eids.astype(str)

# %%
(bim,fam,bed)=read_plink("/work/biobank/ukb_data/GenData/plink")
# Out:
# Mapping files: 100%|██████████| 3/3 [04:29<00:00, 82.28s/it]

# %%
bed.shape
# Out:
# (805426, 488377)

# %%
#eids.columns=["iid"]

# %%
#fam[["iid"]].merge(eids[["iid"]],on="iid")

# %%
print(fam[fam["iid"] =="2900646"])
# Out:
#             fid      iid father mother gender          trait       i
# 464637  2900646  2900646      0      0      1  UKBiLEVEAX_b6  464637

# %%
x=["20002-"+str(j)+"."+str(i) for j in range(4) for i in range(34)]
y=["41202-0."+str(i) for i in range(66)]
z=["41204-0."+str(i) for i in range(184)]

# %%
#x=["50-"+str(j)+".0" for j in range(4)]

# %%
#print(x)

# %%
pd.read_csv("/work/biobank/ukb_data/ukb38722.csv",usecols=["eid"]+x+y+z,low_memory=False)
pheno=pheno.set_index("eid")
pheno.fillna(-1,inplace=True)
p=pheno[pheno["50-0.0"]!=-1]
print(p["50-0.0"])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x99 in position 43: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-149e417295cc> in <module>
# ----> 1 pd.read_csv("/work/biobank/ukb_data/ukb38722.csv",low_memory=False)#,usecols=["eid"]+x+y+z,low_memory=False)
#       2 #pheno=pheno.set_index("eid")
#       3 #pheno.fillna(-1,inplace=True)
# ...

# %%
pheno

# %%
#(bim,fam2,bed)=read_plink("/work/biobank/ukb_data/scripts/heights")

# %%
#pd.DataFrame(np.array([p.index.values,p.index.values]).T.astype(int)).to_csv("/work/biobank/ukb_data/scripts/phenoids.txt",sep="\t",header=False,index=False)

# %%
#np.savetxt('/work/biobank/ukb_data/scripts/phenoids.csv', np.array([p.index.values,p.index.values]).T.astype(int), delimiter='\t')

# %%
#fam2

# %%
#p["50-0.0"].rename_axis("fid")

# %%
#fam["fid"]=fam["fid"].astype(int)

# %%
#fam.set_index("fid",inplace=True)

# %%
#s=p["50-0.0"].rename_axis("fid")

# %%
#s.index

# %%
#pd.DataFrame(np.array([s]).T).boxplot(column=[0])

# %%
"""Size"""
#fam["trait"]=s
# Out:
# 'Size'

# %%
#fam

# %%
#fam.reset_index()

# %%
#fam.reset_index().to_csv("/work/biobank/ukb_data/scripts/heights.fam",header=False,index=False,sep="\t")

# %%
"""Diabetes"""
diabetes=[]
diabetes_41202=[]
length=pheno.index.values.shape[0]
c=1
for i in pheno.index.values:
    print("%d/%d index "%(c,length),end='\r')
    s=pheno.loc[i,:]
    if not (s[s==1223].empty) or (not s[s.str.match("E11*").fillna(False)].empty):
        diabetes.append(i)
    
    c+=1
# Out:
# 502519/502519 index

# %%
#pd.DataFrame(diabetes).to_csv("/work/biobank/ukb_data/indiv_diab.csv",header=False,index=False,sep="\t")

# %%
diabetes=pd.read_csv("/work/biobank/ukb_data/indiv_diab.csv",header=None,sep="\t").T.values[0]

# %%
len(diabetes)
# Out:
# 32884

# %%
diabetes
# Out:
# array([1000118, 1000159, 1000707, ..., 6024936, 6024955, 6025175])

# %%
#fam.loc[diabetes,"trait"]

# %%
fam["fid"]=fam["fid"].astype(int)
fam=fam.set_index("fid")

# %%
#fam.loc[diabetes,"trait"]=1

# %%
c=0
missing=0
l=len(fam.index.values)
for i in fam.index.values:
    print("%d/%d index "%(c,l),end='\r')
    if i in diabetes:
        try:
            fam.loc[i,"trait"]=1
        except:
            missing+=1
    else:
        fam.loc[i,"trait"]=0
    c+=1
# Out:
# 548/488377 index
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-9ccc6208859b> in <module>
#       3 l=len(fam.index.values)
#       4 for i in fam.index.values:
# ----> 5     print("%d/%d index "%(c,l),end='\r')
#       6     if i in diabetes:
#       7         try:
#
# ~/.local/lib/python3.6/site-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~/.local/lib/python3.6/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
# ...

# %%
missing=0
c=0
for i in diabetes:
    print("%d/%d index "%(c,len(diabetes)),end='\r')
    #print(i)
    try:
        #print(fam.loc[i])
        fam.loc[i,"trait"]=1
    except:
        missing+=1
    c+=1
# Out:
# 32883/32884 index

# %%
fam=fam[fam['father'].notnull()]

# %%
fam[fam["trait"]!=1]=0
# Out:
# /home/adbadre/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /opt/oscer/software/pandas/0.21.0-foss-2018a-Python-3.6.4/lib/python3.6/site-packages/pandas-0.21.0-py3.6-linux-x86_64.egg/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ---------------------------------------------------------------------------
# ...

# %%
ind=fam[fam["trait"]!=1].index.values

# %%
fam.loc[ind,"trait"]=0

# %%
fam[fam["trait"]==0]
# Out:
#         iid father mother gender  trait         i
# fid
# 1457772   0      0      0      1      0       0.0
# 3235882   0      0      0      2      0       1.0
# 1860657   0      0      0      2      0       2.0
# 1801526   0      0      0      2      0       3.0
# 2095302   0      0      0      2      0       4.0
# 4249583   0      0      0      1      0       5.0
# 3906633   0      0      0      2      0       6.0
# 3492308   0      0      0      2      0       7.0
# 4843892   0      0      0      1      0       8.0
# 4067386   0      0      0      2      0       9.0
# 5401786   0      0      0      2      0      10.0
# 5696888   0      0      0      2      0      11.0
# 3959531   0      0      0      2      0      12.0
# 5951240   0      0      0      1      0      13.0
# 1060819   0      0      0      2      0      14.0
# 5471075   0      0      0      1      0      15.0
# 2982754   0      0      0      2      0      16.0
# 4011159   0      0      0      1      0      17.0
# ...

# %%
fam.reset_index()
# Out:
#             fid      iid father mother gender  trait         i
# 0       1457772        0      0      0      1      0       0.0
# 1       3235882        0      0      0      2      0       1.0
# 2       1860657        0      0      0      2      0       2.0
# 3       1801526        0      0      0      2      0       3.0
# 4       2095302        0      0      0      2      0       4.0
# 5       4249583        0      0      0      1      0       5.0
# 6       3906633        0      0      0      2      0       6.0
# 7       3492308        0      0      0      2      0       7.0
# 8       4843892        0      0      0      1      0       8.0
# 9       4067386        0      0      0      2      0       9.0
# 10      5401786        0      0      0      2      0      10.0
# 11      5696888        0      0      0      2      0      11.0
# 12      3959531        0      0      0      2      0      12.0
# 13      5951240        0      0      0      1      0      13.0
# ...

# %%
pheno[pheno["42004-0.0"].notnull()]

# %%
a=pd.DataFrame([diabetes]).T
a.columns=["iid"]
a=a.astype(str)

# %%
fam2=fam

# %%
(bim,fam,bed)=read_plink("/work/biobank/ukb_data/GenData/plink")
# Out:
# Mapping files: 100%|██████████| 3/3 [04:55<00:00, 88.78s/it]

# %%
fam.reset_index().to_csv("/work/biobank/ukb_data/scripts/diab.fam",header=False,index=False,sep="\t")

# %%
fam
# Out:
#             fid      iid father mother gender           trait       i
# 0       1457772  1457772      0      0      1      Batch_b001       0
# 1       3235882  3235882      0      0      2      Batch_b001       1
# 2       1860657  1860657      0      0      2      Batch_b001       2
# 3       1801526  1801526      0      0      2      Batch_b001       3
# 4       2095302  2095302      0      0      2      Batch_b001       4
# 5       4249583  4249583      0      0      1      Batch_b001       5
# 6       3906633  3906633      0      0      2      Batch_b001       6
# 7       3492308  3492308      0      0      2      Batch_b001       7
# 8       4843892  4843892      0      0      1      Batch_b001       8
# 9       4067386  4067386      0      0      2      Batch_b001       9
# 10      5401786  5401786      0      0      2      Batch_b001      10
# 11      5696888  5696888      0      0      2      Batch_b001      11
# ...

# %%
fam2.reset_index()
# Out:
#             fid      iid father mother gender  trait         i
# 0       1457772        0      0      0      1      0       0.0
# 1       3235882        0      0      0      2      0       1.0
# 2       1860657        0      0      0      2      0       2.0
# 3       1801526        0      0      0      2      0       3.0
# 4       2095302        0      0      0      2      0       4.0
# 5       4249583        0      0      0      1      0       5.0
# 6       3906633        0      0      0      2      0       6.0
# 7       3492308        0      0      0      2      0       7.0
# 8       4843892        0      0      0      1      0       8.0
# 9       4067386        0      0      0      2      0       9.0
# 10      5401786        0      0      0      2      0      10.0
# 11      5696888        0      0      0      2      0      11.0
# 12      3959531        0      0      0      2      0      12.0
# 13      5951240        0      0      0      1      0      13.0
# ...
